# %%
import sys
sys.path.insert(0, "..")
import seaborn as sns
import chinacolor as ctc
from matplotlib import pyplot as plt
import pandas as pd

# %config InlineBackend.figure_format = 'retina'
ctc.set_default_font_to_packaged()

# %% [markdown]
# # DataFrames
# Access colors and palettes as pandas DataFrames.

# %%
colors = ctc.colors_df()
colors[['color_id','name','hex','group_id','subgroup_id']].head(10)
# Out:
#    color_id name      hex  group_id  subgroup_id
# 0         1  黄白游  #FFF799         1            1
# 1         2   松花  #FFEE6F         1            2
# 2         3   缃叶  #ECD452         1            3
# 3         4   苍黄  #B6A014         1            4
# 4         5   天缥  #D5EBE1         2            1
# 5         6   沧浪  #B1D5C8         2            2
# 6         7   苍筤  #99BCAC         2            3
# 7         8   缥碧  #80A492         2            4
# 8         9   流黄  #8B7042         3            1
# 9        10   栗壳  #775039         3            2

# %%
palettes = ctc.palettes_df()
palettes.head(10)
# Out:
#    index element_name palette_name  palette_name_e        type  color_count
# 0      1        seq01         樱霞晕彩    cherry_blush  sequential            8
# 1      2        seq02         桃影轻霞      peach_glow  sequential            7
# 2      3        seq03         紫韵花影    violet_bloom  sequential            8
# 3      4        seq04         绯影红裳    scarlet_flow  sequential            8
# 4      5        seq05         幽兰绀紫   mystic_purple  sequential            7
# 5      6        seq06         曦光流金    golden_sheen  sequential            5
# 6      7        seq07         焰霞飞舞      flame_glow  sequential            6
# 7      8        seq08         金缕朝霞      amber_dawn  sequential            8
# 8      9        seq09         翠微森语  forest_whisper  sequential           10
# 9     10        seq10         琥珀流光      amber_glow  sequential            7

# %% [markdown]
# # Color grid
# Plot the 24×16 grid of 384 colors (requires CSV metadata).

# %%
ctc.plot_color_grid(show_group=False)
# Out:
# <Axes: title={'center': '384 Traditional Chinese Colors'}>
